# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
from testCases_v4  import *
from dnn_utils_v2 import sigmoid , sigmoid_backward , relu , relu_backward


import scipy
from PIL import Image
from scipy import ndimage
import skimage
from dnn_utils_v2 import *

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0 , 4.0)
plt.rcParams['image.interpolation']= 'nearest'
plt.rcParams['image.cmap']= 'gray'

# %reload_ext autoreload
# %autoreload 2

np.random.seed(1)

# %%
#inicializar parametros
def initialize_parameters_deep(layer_dims):
    np.random.seed(3)
    parameters = {}
    L = len(layer_dims)
    for i in range(1,L):
        parameters["W"+str(i)] =  np.random.randn(layer_dims[int(i)] ,layer_dims[int(i)-1]) *0.01
        parameters["b"+str(i)] =  np.zeros((layer_dims[int(i)] , 1))
        
        print("W" + str(i)  + " = " + str(parameters["W"+str(i)].shape))
        print("b" + str(i)  + " = " + str( parameters["b"+str(i)].shape))
        
        assert(parameters['W' + str(i)].shape == (layer_dims[int(i)], layer_dims[int(i)-1]))
        assert(parameters['b' + str(i)].shape == (layer_dims[int(i)], 1))
    return parameters

# %%
#Probando la función
parameters = initialize_parameters_deep([5,4,3])
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = (4, 5)
# b1 = (4, 1)
# W2 = (3, 4)
# b2 = (3, 1)
# W1 = [[ 0.01788628  0.0043651   0.00096497 -0.01863493 -0.00277388]
#  [-0.00354759 -0.00082741 -0.00627001 -0.00043818 -0.00477218]
#  [-0.01313865  0.00884622  0.00881318  0.01709573  0.00050034]
#  [-0.00404677 -0.0054536  -0.01546477  0.00982367 -0.01101068]]
# b1 = [[0.]
#  [0.]
#  [0.]
#  [0.]]
# W2 = [[-0.01185047 -0.0020565   0.01486148  0.00236716]
#  [-0.01023785 -0.00712993  0.00625245 -0.00160513]
#  [-0.00768836 -0.00230031  0.00745056  0.01976111]]
# b2 = [[0.]
#  [0.]
#  [0.]]

# %%
def linear_forward(A, W, b):
    Z = np.dot(W,A)+b
    assert(Z.shape == (W.shape[0], A.shape[1]))
    cache = (A, W, b)
    return Z, cache

# %%
#Probando la función
A, W, b = linear_forward_test_case()
Z, linear_cache = linear_forward(A, W, b)
print("Z = " + str(Z))
# Out:
# Z = [[ 3.26295337 -1.23429987]]

# %%
def linear_activation_forward(A_prev, W, b, activation):
    if activation == "sigmoid":
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = sigmoid(Z)
    
    elif activation == "relu":
        Z, linear_cache = linear_forward(A_prev, W, b)
        A, activation_cache = relu(Z)
    
    assert (A.shape == (W.shape[0], A_prev.shape[1]))
    cache = (linear_cache, activation_cache)
    return A, cache

# %%
#Probando a la función
A_prev, W, b = linear_activation_forward_test_case()
A, linear_activation_cache = linear_activation_forward(A_prev, W, b, activation = "sigmoid")
print("With sigmoid: A = " + str(A))
A, linear_activation_cache = linear_activation_forward(A_prev, W, b, activation = "relu")
print("With ReLU: A = " + str(A))
# Out:
# With sigmoid: A = [[0.96890023 0.11013289]]
# With ReLU: A = [[3.43896131 0.        ]]

# %%
def L_model_forward(X, parameters):
    
    caches =[]
    A=X;
    L=len(parameters)//2
    caches=list()
    
    # Implemente [LINEAR -> RELU]*(L-1). Agregue "cache" a la lista "caches"
    
    for l in range(1,L):
        A_prev = A
        A , cache = linear_activation_forward(A_prev, parameters["W" + str(l)] , parameters["b" + str(l)], activation = "relu")
        caches.append(cache)
        
     # Implementa LINEAR -> SIGMOID. Agregue "cache" a la lista "caches"
    AL, cache = linear_activation_forward(A , parameters["W" + str(L)] , parameters["b" + str(L)], activation = "sigmoid" )
    caches.append(cache)
    return AL, caches

# %%
X, parameters = L_model_forward_test_case_2hidden()
AL, caches = L_model_forward(X, parameters)
print("AL = " + str(AL))
print("Length of caches list = " + str(len(caches)))
# Out:
# AL = [[0.03921668 0.70498921 0.19734387 0.04728177]]
# Length of caches list = 3

# %%
def compute_cost (AL,Y):
    m = Y.shape[1]
    
    cost = ( np.sum( np.dot( Y,np.log(AL).T ) + np.dot( ( 1-Y ),( np.log(1-AL).T ) ) ) )/(-m)
    
    cost = np.squeeze(cost)
    assert( cost.shape == () )
    return cost

# %%
Y, AL = compute_cost_test_case()
print("cost = " + str(compute_cost(AL, Y)))
# Out:
# cost = 0.414931599615397

# %%
def linear_backward(dZ, cache):
    A_prev, W, b = cache
    m = A_prev.shape[1]
    
    dW = ( np.dot( dZ,A_prev.T) )/(m)
    db = ( np.sum(dZ , axis=1, keepdims=True) )/(m)
    dA_prev = np.dot( W.T,dZ )

    assert (dA_prev.shape == A_prev.shape)
    assert (dW.shape == W.shape)
    assert (db.shape == b.shape)

    return dA_prev, dW, db

# %%
#Probando la función
dZ, linear_cache = linear_backward_test_case()
dA_prev, dW, db = linear_backward(dZ, linear_cache)
print ("dA_prev = "+ str(dA_prev))
print ("dW = " + str(dW))
print ("db = " + str(db))
# Out:
# dA_prev = [[ 0.51822968 -0.19517421]
#  [-0.40506361  0.15255393]
#  [ 2.37496825 -0.89445391]]
# dW = [[-0.10076895  1.40685096  1.64992505]]
# db = [[0.50629448]]

# %%
def linear_activation_backward(dA, cache, activation):
    linear_cache, activation_cache = cache
    
    if activation == "relu":
        dZ =  relu_backward (dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
    
    elif activation == "sigmoid":
        dZ = sigmoid_backward (dA, activation_cache)
        dA_prev, dW, db = linear_backward(dZ, linear_cache)
    
    return dA_prev, dW, db

# %%
#Probando la función
dAL, linear_activation_cache = linear_activation_backward_test_case()
dA_prev, dW, db = linear_activation_backward(dAL, linear_activation_cache, activation = "sigmoid")
print ("sigmoid:")
print ("dA_prev = "+ str(dA_prev))
print ("dW = " + str(dW))
print ("db = " + str(db) + "\n")
dA_prev, dW, db = linear_activation_backward(dAL, linear_activation_cache, activation = "relu")
print ("relu:")
print ("dA_prev = "+ str(dA_prev))
print ("dW = " + str(dW))
print ("db = " + str(db))
# Out:
# sigmoid:
# dA_prev = [[ 0.11017994  0.01105339]
#  [ 0.09466817  0.00949723]
#  [-0.05743092 -0.00576154]]
# dW = [[ 0.10266786  0.09778551 -0.01968084]]
# db = [[-0.05729622]]
#
# relu:
# dA_prev = [[ 0.44090989 -0.        ]
#  [ 0.37883606 -0.        ]
#  [-0.2298228   0.        ]]
# dW = [[ 0.44513824  0.37371418 -0.10478989]]
# db = [[-0.20837892]]

# %%
def L_model_backward(AL, Y, caches):
    grads = {}
    L = len(caches) # the number of layers
    m = AL.shape[1]
    Y = Y.reshape(AL.shape) # after this line, Y is the same shape as AL

    # Iniciando el backpropagation
    dAL = - (np.divide(Y, AL) - np.divide(1 - Y, 1 - AL))

    # en cada capa l (SIGMOID -> LINEAR) gradients. Entrada: "dAL, current_cache". Salida: 
    # "grads["dAL-1"], grads["dWL"], grads["dbL"]
    current_cache = caches[L-1] 
    grads["dA" + str(L-1)], grads["dW" + str(L)], grads["db" + str(L)] = linear_activation_backward( dAL, current_cache, "sigmoid" )

    # Loop de l=L-2 to l=0
    for l in reversed(range(L-1)):
        current_cache = caches[l]
        dA_prev_temp, dW_temp, db_temp = linear_activation_backward(grads["dA" + str(l+1)],current_cache,"relu")
    
        grads["dA" + str(l)] = dA_prev_temp
        grads["dW" + str(l + 1)] = dW_temp
        grads["db" + str(l + 1)] = db_temp
    return grads

# %%
#Probando la función
AL, Y_assess, caches = L_model_backward_test_case()
grads = L_model_backward(AL , Y_assess , caches)
print_grads(grads)
# Out:
# dW1 = [[0.41010002 0.07807203 0.13798444 0.10502167]
#  [0.         0.         0.         0.        ]
#  [0.05283652 0.01005865 0.01777766 0.0135308 ]]
# db1 = [[-0.22007063]
#  [ 0.        ]
#  [-0.02835349]]
# dA1 = [[ 0.12913162 -0.44014127]
#  [-0.14175655  0.48317296]
#  [ 0.01663708 -0.05670698]]

# %%
def update_parameters(parameters, grads, learning_rate):
    L = len(parameters) // 2 # numero de capas de la red
    for l in range(L):
        parameters["W" + str(l+1)] = (parameters["W"+ str(l+1)]  - learning_rate*grads["dW"+ str(l+1)])
        parameters["b" + str(l+1)] = (parameters["b"+ str(l+1)]  - learning_rate*grads["db"+ str(l+1)])
    return parameters

# %%
parameters, grads = update_parameters_test_case()
parameters = update_parameters(parameters, grads, 0.1)
print ("W1 = "+ str(parameters["W1"]))
print ("b1 = "+ str(parameters["b1"]))
print ("W2 = "+ str(parameters["W2"]))
print ("b2 = "+ str(parameters["b2"]))
# Out:
# W1 = [[-0.59562069 -0.09991781 -2.14584584  1.82662008]
#  [-1.76569676 -0.80627147  0.51115557 -1.18258802]
#  [-1.0535704  -0.86128581  0.68284052  2.20374577]]
# b1 = [[-0.04659241]
#  [-1.28888275]
#  [ 0.53405496]]
# W2 = [[-0.55569196  0.0354055   1.32964895]]
# b2 = [[-0.84610769]]

# %%
def nn_model(X, Y, layer_dims , num_iterations = 10000, learning_rate=1.2 , print_cost=False):
    
    np.random.seed(1)
    
    parameters = initialize_parameters_deep(capas)
    costo=[]
    
    for i in range(num_iterations):
        #FORWARD PROGATION
        AL , caches = L_model_forward(X, parameters) 
        
        #CALCULA FUNCION COSTO
        cost = compute_cost(AL , Y)
        
        #BACK PROGATION
        grads = L_model_backward(AL, Y, caches)
        
        #ACTUALIZACION DE PESOS 
        parameters = update_parameters(parameters, grads , learning_rate)
        
        if print_cost and i % 10 == 0:
            print ("Costo despues de iteracion: ",i," = ", cost)
        if  i % 1000 == 0:
            costo.append(cost)
    return parameters

# %%
def predict(parameters, X):
    A2, cache = L_model_forward(X, parameters)
    predictions = np.rint(A2)
    return predictions

# %%
#OBTECION DE DATOS
def load_dataset():
    train_dataset = h5py.File('datasets/train_catvnoncat.h5', "r")
    train_set_x_orig = np.array(train_dataset["train_set_x"][:])
    train_set_y_orig = np.array(train_dataset["train_set_y"][:])
    test_dataset = h5py.File('datasets/test_catvnoncat.h5', "r")
    test_set_x_orig = np.array(test_dataset["test_set_x"][:])
    test_set_y_orig = np.array(test_dataset["test_set_y"][:])
    classes = np.array(test_dataset["list_classes"][:])
    train_set_y_orig = train_set_y_orig.reshape((1, train_set_y_orig.shape[0]))
    test_set_y_orig = test_set_y_orig.reshape((1, test_set_y_orig.shape[0]))#---
    return train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes

# %%
train_x_orig, train_y, test_x_orig, test_y, classes = load_dataset()
m_train = train_x_orig.shape[0]
num_px = train_x_orig.shape[1]
m_test = test_x_orig.shape[0]

train_x_flatten = train_x_orig.reshape(train_x_orig.shape[0], -1).T  
test_x_flatten = test_x_orig.reshape(test_x_orig.shape[0], -1).T

train_x = train_x_flatten/255.
test_x = test_x_flatten/255.

# %%
capas = [12288,1]

# %%
parameters  = nn_model(train_set_x,  Y , layer_dims  , 10000 , 1.3 , print_cost=True )
# Out:
# W1 = (1, 12288)
# b1 = (1, 1)
# Costo despues de iteracion:  0  =  0.6909085741648417
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: divide by zero encountered in true_divide
#
# C:\Users\Lenovo\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide
#
# C:\Users\Lenovo\UNA\REDES PROFUNDAS\RED-NUERONAL-PROFUNDA\dnn_utils_v2.py:77: RuntimeWarning: invalid value encountered in multiply
#   dZ = dA * s * (1-s)
# Costo despues de iteracion:  10  =  nan
# Costo despues de iteracion:  20  =  nan
# Costo despues de iteracion:  30  =  nan
# Costo despues de iteracion:  40  =  nan
# Costo despues de iteracion:  50  =  nan
# Costo despues de iteracion:  60  =  nan
# Costo despues de iteracion:  70  =  nan
# Costo despues de iteracion:  80  =  nan
# Costo despues de iteracion:  90  =  nan
# Costo despues de iteracion:  100  =  nan
# Costo despues de iteracion:  110  =  nan
# Costo despues de iteracion:  120  =  nan
# Costo despues de iteracion:  130  =  nan
# Costo despues de iteracion:  140  =  nan
# Costo despues de iteracion:  150  =  nan
# Costo despues de iteracion:  160  =  nan
# Costo despues de iteracion:  170  =  nan
# Costo despues de iteracion:  180  =  nan
# Costo despues de iteracion:  190  =  nan
# Costo despues de iteracion:  200  =  nan
# Costo despues de iteracion:  210  =  nan
# Costo despues de iteracion:  220  =  nan
# Costo despues de iteracion:  230  =  nan
# Costo despues de iteracion:  240  =  nan
# Costo despues de iteracion:  250  =  nan
# Costo despues de iteracion:  260  =  nan
# Costo despues de iteracion:  270  =  nan
# Costo despues de iteracion:  280  =  nan
# Costo despues de iteracion:  290  =  nan
# Costo despues de iteracion:  300  =  nan
# Costo despues de iteracion:  310  =  nan
# Costo despues de iteracion:  320  =  nan
# Costo despues de iteracion:  330  =  nan
# Costo despues de iteracion:  340  =  nan
# Costo despues de iteracion:  350  =  nan
# Costo despues de iteracion:  360  =  nan
# Costo despues de iteracion:  370  =  nan
# Costo despues de iteracion:  380  =  nan
# Costo despues de iteracion:  390  =  nan
# Costo despues de iteracion:  400  =  nan
# Costo despues de iteracion:  410  =  nan
# Costo despues de iteracion:  420  =  nan
# Costo despues de iteracion:  430  =  nan
# Costo despues de iteracion:  440  =  nan
# Costo despues de iteracion:  450  =  nan
# Costo despues de iteracion:  460  =  nan
# Costo despues de iteracion:  470  =  nan
# Costo despues de iteracion:  480  =  nan
# Costo despues de iteracion:  490  =  nan
# Costo despues de iteracion:  500  =  nan
# Costo despues de iteracion:  510  =  nan
# Costo despues de iteracion:  520  =  nan
# Costo despues de iteracion:  530  =  nan
# Costo despues de iteracion:  540  =  nan
# Costo despues de iteracion:  550  =  nan
# Costo despues de iteracion:  560  =  nan
# Costo despues de iteracion:  570  =  nan
# Costo despues de iteracion:  580  =  nan
# Costo despues de iteracion:  590  =  nan
# Costo despues de iteracion:  600  =  nan
# Costo despues de iteracion:  610  =  nan
# Costo despues de iteracion:  620  =  nan
# Costo despues de iteracion:  630  =  nan
# Costo despues de iteracion:  640  =  nan
# Costo despues de iteracion:  650  =  nan
# Costo despues de iteracion:  660  =  nan
# Costo despues de iteracion:  670  =  nan
# Costo despues de iteracion:  680  =  nan
# Costo despues de iteracion:  690  =  nan
# Costo despues de iteracion:  700  =  nan
# Costo despues de iteracion:  710  =  nan
# Costo despues de iteracion:  720  =  nan
# Costo despues de iteracion:  730  =  nan
# Costo despues de iteracion:  740  =  nan
# Costo despues de iteracion:  750  =  nan
# Costo despues de iteracion:  760  =  nan
# Costo despues de iteracion:  770  =  nan
# Costo despues de iteracion:  780  =  nan
# Costo despues de iteracion:  790  =  nan
# Costo despues de iteracion:  800  =  nan
# Costo despues de iteracion:  810  =  nan
# Costo despues de iteracion:  820  =  nan
# Costo despues de iteracion:  830  =  nan
# Costo despues de iteracion:  840  =  nan
# Costo despues de iteracion:  850  =  nan
# Costo despues de iteracion:  860  =  nan
# Costo despues de iteracion:  870  =  nan
# Costo despues de iteracion:  880  =  nan
# Costo despues de iteracion:  890  =  nan
# Costo despues de iteracion:  900  =  nan
# Costo despues de iteracion:  910  =  nan
# Costo despues de iteracion:  920  =  nan
# Costo despues de iteracion:  930  =  nan
# Costo despues de iteracion:  940  =  nan
# Costo despues de iteracion:  950  =  nan
# Costo despues de iteracion:  960  =  nan
# Costo despues de iteracion:  970  =  nan
# Costo despues de iteracion:  980  =  nan
# Costo despues de iteracion:  990  =  nan
# Costo despues de iteracion:  1000  =  nan
# Costo despues de iteracion:  1010  =  nan
# Costo despues de iteracion:  1020  =  nan
# Costo despues de iteracion:  1030  =  nan
# Costo despues de iteracion:  1040  =  nan
# Costo despues de iteracion:  1050  =  nan
# Costo despues de iteracion:  1060  =  nan
# Costo despues de iteracion:  1070  =  nan
# Costo despues de iteracion:  1080  =  nan
# Costo despues de iteracion:  1090  =  nan
# Costo despues de iteracion:  1100  =  nan
# Costo despues de iteracion:  1110  =  nan
# Costo despues de iteracion:  1120  =  nan
# Costo despues de iteracion:  1130  =  nan
# Costo despues de iteracion:  1140  =  nan
# Costo despues de iteracion:  1150  =  nan
# Costo despues de iteracion:  1160  =  nan
# Costo despues de iteracion:  1170  =  nan
# Costo despues de iteracion:  1180  =  nan
# Costo despues de iteracion:  1190  =  nan
# Costo despues de iteracion:  1200  =  nan
# Costo despues de iteracion:  1210  =  nan
# Costo despues de iteracion:  1220  =  nan
# Costo despues de iteracion:  1230  =  nan
# Costo despues de iteracion:  1240  =  nan
# Costo despues de iteracion:  1250  =  nan
# Costo despues de iteracion:  1260  =  nan
# Costo despues de iteracion:  1270  =  nan
# Costo despues de iteracion:  1280  =  nan
# Costo despues de iteracion:  1290  =  nan
# Costo despues de iteracion:  1300  =  nan
# Costo despues de iteracion:  1310  =  nan
# Costo despues de iteracion:  1320  =  nan
# Costo despues de iteracion:  1330  =  nan
# Costo despues de iteracion:  1340  =  nan
# Costo despues de iteracion:  1350  =  nan
# Costo despues de iteracion:  1360  =  nan
# Costo despues de iteracion:  1370  =  nan
# Costo despues de iteracion:  1380  =  nan
# Costo despues de iteracion:  1390  =  nan
# Costo despues de iteracion:  1400  =  nan
# Costo despues de iteracion:  1410  =  nan
# Costo despues de iteracion:  1420  =  nan
# Costo despues de iteracion:  1430  =  nan
# Costo despues de iteracion:  1440  =  nan
# Costo despues de iteracion:  1450  =  nan
# Costo despues de iteracion:  1460  =  nan
# Costo despues de iteracion:  1470  =  nan
# Costo despues de iteracion:  1480  =  nan
# Costo despues de iteracion:  1490  =  nan
# Costo despues de iteracion:  1500  =  nan
# Costo despues de iteracion:  1510  =  nan
# Costo despues de iteracion:  1520  =  nan
# Costo despues de iteracion:  1530  =  nan
# Costo despues de iteracion:  1540  =  nan
# Costo despues de iteracion:  1550  =  nan
# Costo despues de iteracion:  1560  =  nan
# Costo despues de iteracion:  1570  =  nan
# Costo despues de iteracion:  1580  =  nan
# Costo despues de iteracion:  1590  =  nan
# Costo despues de iteracion:  1600  =  nan
# Costo despues de iteracion:  1610  =  nan
# Costo despues de iteracion:  1620  =  nan
# Costo despues de iteracion:  1630  =  nan
# Costo despues de iteracion:  1640  =  nan
# Costo despues de iteracion:  1650  =  nan
# Costo despues de iteracion:  1660  =  nan
# Costo despues de iteracion:  1670  =  nan
# Costo despues de iteracion:  1680  =  nan
# Costo despues de iteracion:  1690  =  nan
# Costo despues de iteracion:  1700  =  nan
# Costo despues de iteracion:  1710  =  nan
# Costo despues de iteracion:  1720  =  nan
# Costo despues de iteracion:  1730  =  nan
# Costo despues de iteracion:  1740  =  nan
# Costo despues de iteracion:  1750  =  nan
# Costo despues de iteracion:  1760  =  nan
# Costo despues de iteracion:  1770  =  nan
# Costo despues de iteracion:  1780  =  nan
# Costo despues de iteracion:  1790  =  nan
# Costo despues de iteracion:  1800  =  nan
# Costo despues de iteracion:  1810  =  nan
# Costo despues de iteracion:  1820  =  nan
# Costo despues de iteracion:  1830  =  nan
# Costo despues de iteracion:  1840  =  nan
# Costo despues de iteracion:  1850  =  nan
# Costo despues de iteracion:  1860  =  nan
# Costo despues de iteracion:  1870  =  nan
# Costo despues de iteracion:  1880  =  nan
# Costo despues de iteracion:  1890  =  nan
# Costo despues de iteracion:  1900  =  nan
# Costo despues de iteracion:  1910  =  nan
# Costo despues de iteracion:  1920  =  nan
# Costo despues de iteracion:  1930  =  nan
# Costo despues de iteracion:  1940  =  nan
# Costo despues de iteracion:  1950  =  nan
# Costo despues de iteracion:  1960  =  nan
# Costo despues de iteracion:  1970  =  nan
# Costo despues de iteracion:  1980  =  nan
# Costo despues de iteracion:  1990  =  nan
# Costo despues de iteracion:  2000  =  nan
# Costo despues de iteracion:  2010  =  nan
# Costo despues de iteracion:  2020  =  nan
# Costo despues de iteracion:  2030  =  nan
# Costo despues de iteracion:  2040  =  nan
# Costo despues de iteracion:  2050  =  nan
# Costo despues de iteracion:  2060  =  nan
# Costo despues de iteracion:  2070  =  nan
# Costo despues de iteracion:  2080  =  nan
# Costo despues de iteracion:  2090  =  nan
# Costo despues de iteracion:  2100  =  nan
# Costo despues de iteracion:  2110  =  nan
# Costo despues de iteracion:  2120  =  nan
# Costo despues de iteracion:  2130  =  nan
# Costo despues de iteracion:  2140  =  nan
# Costo despues de iteracion:  2150  =  nan
# Costo despues de iteracion:  2160  =  nan
# Costo despues de iteracion:  2170  =  nan
# Costo despues de iteracion:  2180  =  nan
# Costo despues de iteracion:  2190  =  nan
# Costo despues de iteracion:  2200  =  nan
# Costo despues de iteracion:  2210  =  nan
# Costo despues de iteracion:  2220  =  nan
# Costo despues de iteracion:  2230  =  nan
# Costo despues de iteracion:  2240  =  nan
# Costo despues de iteracion:  2250  =  nan
# Costo despues de iteracion:  2260  =  nan
# Costo despues de iteracion:  2270  =  nan
# Costo despues de iteracion:  2280  =  nan
# Costo despues de iteracion:  2290  =  nan
# Costo despues de iteracion:  2300  =  nan
# Costo despues de iteracion:  2310  =  nan
# Costo despues de iteracion:  2320  =  nan
# Costo despues de iteracion:  2330  =  nan
# Costo despues de iteracion:  2340  =  nan
# Costo despues de iteracion:  2350  =  nan
# Costo despues de iteracion:  2360  =  nan
# Costo despues de iteracion:  2370  =  nan
# Costo despues de iteracion:  2380  =  nan
# Costo despues de iteracion:  2390  =  nan
# Costo despues de iteracion:  2400  =  nan
# Costo despues de iteracion:  2410  =  nan
# Costo despues de iteracion:  2420  =  nan
# Costo despues de iteracion:  2430  =  nan
# Costo despues de iteracion:  2440  =  nan
# Costo despues de iteracion:  2450  =  nan
# Costo despues de iteracion:  2460  =  nan
# Costo despues de iteracion:  2470  =  nan
# Costo despues de iteracion:  2480  =  nan
# Costo despues de iteracion:  2490  =  nan
# Costo despues de iteracion:  2500  =  nan
# Costo despues de iteracion:  2510  =  nan
# Costo despues de iteracion:  2520  =  nan
# Costo despues de iteracion:  2530  =  nan
# Costo despues de iteracion:  2540  =  nan
# Costo despues de iteracion:  2550  =  nan
# Costo despues de iteracion:  2560  =  nan
# Costo despues de iteracion:  2570  =  nan
# Costo despues de iteracion:  2580  =  nan
# Costo despues de iteracion:  2590  =  nan
# Costo despues de iteracion:  2600  =  nan
# Costo despues de iteracion:  2610  =  nan
# Costo despues de iteracion:  2620  =  nan
# Costo despues de iteracion:  2630  =  nan
# Costo despues de iteracion:  2640  =  nan
# Costo despues de iteracion:  2650  =  nan
# Costo despues de iteracion:  2660  =  nan
# Costo despues de iteracion:  2670  =  nan
# Costo despues de iteracion:  2680  =  nan
# Costo despues de iteracion:  2690  =  nan
# Costo despues de iteracion:  2700  =  nan
# Costo despues de iteracion:  2710  =  nan
# Costo despues de iteracion:  2720  =  nan
# Costo despues de iteracion:  2730  =  nan
# Costo despues de iteracion:  2740  =  nan
# Costo despues de iteracion:  2750  =  nan
# Costo despues de iteracion:  2760  =  nan
# Costo despues de iteracion:  2770  =  nan
# Costo despues de iteracion:  2780  =  nan
# Costo despues de iteracion:  2790  =  nan
# Costo despues de iteracion:  2800  =  nan
# Costo despues de iteracion:  2810  =  nan
# Costo despues de iteracion:  2820  =  nan
# Costo despues de iteracion:  2830  =  nan
# Costo despues de iteracion:  2840  =  nan
# Costo despues de iteracion:  2850  =  nan
# Costo despues de iteracion:  2860  =  nan
# Costo despues de iteracion:  2870  =  nan
# Costo despues de iteracion:  2880  =  nan
# Costo despues de iteracion:  2890  =  nan
# Costo despues de iteracion:  2900  =  nan
# Costo despues de iteracion:  2910  =  nan
# Costo despues de iteracion:  2920  =  nan
# Costo despues de iteracion:  2930  =  nan
# Costo despues de iteracion:  2940  =  nan
# Costo despues de iteracion:  2950  =  nan
# Costo despues de iteracion:  2960  =  nan
# Costo despues de iteracion:  2970  =  nan
# Costo despues de iteracion:  2980  =  nan
# Costo despues de iteracion:  2990  =  nan
# Costo despues de iteracion:  3000  =  nan
# Costo despues de iteracion:  3010  =  nan
# Costo despues de iteracion:  3020  =  nan
# Costo despues de iteracion:  3030  =  nan
# Costo despues de iteracion:  3040  =  nan
# Costo despues de iteracion:  3050  =  nan
# Costo despues de iteracion:  3060  =  nan
# Costo despues de iteracion:  3070  =  nan
# Costo despues de iteracion:  3080  =  nan
# Costo despues de iteracion:  3090  =  nan
# Costo despues de iteracion:  3100  =  nan
# Costo despues de iteracion:  3110  =  nan
# Costo despues de iteracion:  3120  =  nan
# Costo despues de iteracion:  3130  =  nan
# Costo despues de iteracion:  3140  =  nan
# Costo despues de iteracion:  3150  =  nan
# Costo despues de iteracion:  3160  =  nan
# Costo despues de iteracion:  3170  =  nan
# Costo despues de iteracion:  3180  =  nan
# Costo despues de iteracion:  3190  =  nan
# Costo despues de iteracion:  3200  =  nan
# Costo despues de iteracion:  3210  =  nan
# Costo despues de iteracion:  3220  =  nan
# Costo despues de iteracion:  3230  =  nan
# Costo despues de iteracion:  3240  =  nan
# Costo despues de iteracion:  3250  =  nan
# Costo despues de iteracion:  3260  =  nan
# Costo despues de iteracion:  3270  =  nan
# Costo despues de iteracion:  3280  =  nan
# Costo despues de iteracion:  3290  =  nan
# Costo despues de iteracion:  3300  =  nan
# Costo despues de iteracion:  3310  =  nan
# Costo despues de iteracion:  3320  =  nan
# Costo despues de iteracion:  3330  =  nan
# Costo despues de iteracion:  3340  =  nan
# Costo despues de iteracion:  3350  =  nan
# Costo despues de iteracion:  3360  =  nan
# Costo despues de iteracion:  3370  =  nan
# Costo despues de iteracion:  3380  =  nan
# Costo despues de iteracion:  3390  =  nan
# Costo despues de iteracion:  3400  =  nan
# Costo despues de iteracion:  3410  =  nan
# Costo despues de iteracion:  3420  =  nan
# Costo despues de iteracion:  3430  =  nan
# Costo despues de iteracion:  3440  =  nan
# Costo despues de iteracion:  3450  =  nan
# Costo despues de iteracion:  3460  =  nan
# Costo despues de iteracion:  3470  =  nan
# Costo despues de iteracion:  3480  =  nan
# Costo despues de iteracion:  3490  =  nan
# Costo despues de iteracion:  3500  =  nan
# Costo despues de iteracion:  3510  =  nan
# Costo despues de iteracion:  3520  =  nan
# Costo despues de iteracion:  3530  =  nan
# Costo despues de iteracion:  3540  =  nan
# Costo despues de iteracion:  3550  =  nan
# Costo despues de iteracion:  3560  =  nan
# Costo despues de iteracion:  3570  =  nan
# Costo despues de iteracion:  3580  =  nan
# Costo despues de iteracion:  3590  =  nan
# Costo despues de iteracion:  3600  =  nan
# Costo despues de iteracion:  3610  =  nan
# Costo despues de iteracion:  3620  =  nan
# Costo despues de iteracion:  3630  =  nan
# Costo despues de iteracion:  3640  =  nan
# Costo despues de iteracion:  3650  =  nan
# Costo despues de iteracion:  3660  =  nan
# Costo despues de iteracion:  3670  =  nan
# Costo despues de iteracion:  3680  =  nan
# Costo despues de iteracion:  3690  =  nan
# Costo despues de iteracion:  3700  =  nan
# Costo despues de iteracion:  3710  =  nan
# Costo despues de iteracion:  3720  =  nan
# Costo despues de iteracion:  3730  =  nan
# Costo despues de iteracion:  3740  =  nan
# Costo despues de iteracion:  3750  =  nan
# Costo despues de iteracion:  3760  =  nan
# Costo despues de iteracion:  3770  =  nan
# Costo despues de iteracion:  3780  =  nan
# Costo despues de iteracion:  3790  =  nan
# Costo despues de iteracion:  3800  =  nan
# Costo despues de iteracion:  3810  =  nan
# Costo despues de iteracion:  3820  =  nan
# Costo despues de iteracion:  3830  =  nan
# Costo despues de iteracion:  3840  =  nan
# Costo despues de iteracion:  3850  =  nan
# Costo despues de iteracion:  3860  =  nan
# Costo despues de iteracion:  3870  =  nan
# Costo despues de iteracion:  3880  =  nan
# Costo despues de iteracion:  3890  =  nan
# Costo despues de iteracion:  3900  =  nan
# Costo despues de iteracion:  3910  =  nan
# Costo despues de iteracion:  3920  =  nan
# Costo despues de iteracion:  3930  =  nan
# Costo despues de iteracion:  3940  =  nan
# Costo despues de iteracion:  3950  =  nan
# Costo despues de iteracion:  3960  =  nan
# Costo despues de iteracion:  3970  =  nan
# Costo despues de iteracion:  3980  =  nan
# Costo despues de iteracion:  3990  =  nan
# Costo despues de iteracion:  4000  =  nan
# Costo despues de iteracion:  4010  =  nan
# Costo despues de iteracion:  4020  =  nan
# Costo despues de iteracion:  4030  =  nan
# Costo despues de iteracion:  4040  =  nan
# Costo despues de iteracion:  4050  =  nan
# Costo despues de iteracion:  4060  =  nan
# Costo despues de iteracion:  4070  =  nan
# Costo despues de iteracion:  4080  =  nan
# Costo despues de iteracion:  4090  =  nan
# Costo despues de iteracion:  4100  =  nan
# Costo despues de iteracion:  4110  =  nan
# Costo despues de iteracion:  4120  =  nan
# Costo despues de iteracion:  4130  =  nan
# Costo despues de iteracion:  4140  =  nan
# Costo despues de iteracion:  4150  =  nan
# Costo despues de iteracion:  4160  =  nan
# Costo despues de iteracion:  4170  =  nan
# Costo despues de iteracion:  4180  =  nan
# Costo despues de iteracion:  4190  =  nan
# Costo despues de iteracion:  4200  =  nan
# Costo despues de iteracion:  4210  =  nan
# Costo despues de iteracion:  4220  =  nan
# Costo despues de iteracion:  4230  =  nan
# Costo despues de iteracion:  4240  =  nan
# Costo despues de iteracion:  4250  =  nan
# Costo despues de iteracion:  4260  =  nan
# Costo despues de iteracion:  4270  =  nan
# Costo despues de iteracion:  4280  =  nan
# Costo despues de iteracion:  4290  =  nan
# Costo despues de iteracion:  4300  =  nan
# Costo despues de iteracion:  4310  =  nan
# Costo despues de iteracion:  4320  =  nan
# Costo despues de iteracion:  4330  =  nan
# Costo despues de iteracion:  4340  =  nan
# Costo despues de iteracion:  4350  =  nan
# Costo despues de iteracion:  4360  =  nan
# Costo despues de iteracion:  4370  =  nan
# Costo despues de iteracion:  4380  =  nan
# Costo despues de iteracion:  4390  =  nan
# Costo despues de iteracion:  4400  =  nan
# Costo despues de iteracion:  4410  =  nan
# Costo despues de iteracion:  4420  =  nan
# Costo despues de iteracion:  4430  =  nan
# Costo despues de iteracion:  4440  =  nan
# Costo despues de iteracion:  4450  =  nan
# Costo despues de iteracion:  4460  =  nan
# Costo despues de iteracion:  4470  =  nan
# Costo despues de iteracion:  4480  =  nan
# Costo despues de iteracion:  4490  =  nan
# Costo despues de iteracion:  4500  =  nan
# Costo despues de iteracion:  4510  =  nan
# Costo despues de iteracion:  4520  =  nan
# Costo despues de iteracion:  4530  =  nan
# Costo despues de iteracion:  4540  =  nan
# Costo despues de iteracion:  4550  =  nan
# Costo despues de iteracion:  4560  =  nan
# Costo despues de iteracion:  4570  =  nan
# Costo despues de iteracion:  4580  =  nan
# Costo despues de iteracion:  4590  =  nan
# Costo despues de iteracion:  4600  =  nan
# Costo despues de iteracion:  4610  =  nan
# Costo despues de iteracion:  4620  =  nan
# Costo despues de iteracion:  4630  =  nan
# Costo despues de iteracion:  4640  =  nan
# Costo despues de iteracion:  4650  =  nan
# Costo despues de iteracion:  4660  =  nan
# Costo despues de iteracion:  4670  =  nan
# Costo despues de iteracion:  4680  =  nan
# Costo despues de iteracion:  4690  =  nan
# Costo despues de iteracion:  4700  =  nan
# Costo despues de iteracion:  4710  =  nan
# Costo despues de iteracion:  4720  =  nan
# Costo despues de iteracion:  4730  =  nan
# Costo despues de iteracion:  4740  =  nan
# Costo despues de iteracion:  4750  =  nan
# Costo despues de iteracion:  4760  =  nan
# Costo despues de iteracion:  4770  =  nan
# Costo despues de iteracion:  4780  =  nan
# Costo despues de iteracion:  4790  =  nan
# Costo despues de iteracion:  4800  =  nan
# Costo despues de iteracion:  4810  =  nan
# Costo despues de iteracion:  4820  =  nan
# Costo despues de iteracion:  4830  =  nan
# Costo despues de iteracion:  4840  =  nan
# Costo despues de iteracion:  4850  =  nan
# Costo despues de iteracion:  4860  =  nan
# Costo despues de iteracion:  4870  =  nan
# Costo despues de iteracion:  4880  =  nan
# Costo despues de iteracion:  4890  =  nan
# Costo despues de iteracion:  4900  =  nan
# Costo despues de iteracion:  4910  =  nan
# Costo despues de iteracion:  4920  =  nan
# Costo despues de iteracion:  4930  =  nan
# Costo despues de iteracion:  4940  =  nan
# Costo despues de iteracion:  4950  =  nan
# Costo despues de iteracion:  4960  =  nan
# Costo despues de iteracion:  4970  =  nan
# Costo despues de iteracion:  4980  =  nan
# Costo despues de iteracion:  4990  =  nan
# Costo despues de iteracion:  5000  =  nan
# Costo despues de iteracion:  5010  =  nan
# Costo despues de iteracion:  5020  =  nan
# Costo despues de iteracion:  5030  =  nan
# Costo despues de iteracion:  5040  =  nan
# Costo despues de iteracion:  5050  =  nan
# Costo despues de iteracion:  5060  =  nan
# Costo despues de iteracion:  5070  =  nan
# Costo despues de iteracion:  5080  =  nan
# Costo despues de iteracion:  5090  =  nan
# Costo despues de iteracion:  5100  =  nan
# Costo despues de iteracion:  5110  =  nan
# Costo despues de iteracion:  5120  =  nan
# Costo despues de iteracion:  5130  =  nan
# Costo despues de iteracion:  5140  =  nan
# Costo despues de iteracion:  5150  =  nan
# Costo despues de iteracion:  5160  =  nan
# Costo despues de iteracion:  5170  =  nan
# Costo despues de iteracion:  5180  =  nan
# Costo despues de iteracion:  5190  =  nan
# Costo despues de iteracion:  5200  =  nan
# Costo despues de iteracion:  5210  =  nan
# Costo despues de iteracion:  5220  =  nan
# Costo despues de iteracion:  5230  =  nan
# Costo despues de iteracion:  5240  =  nan
# Costo despues de iteracion:  5250  =  nan
# Costo despues de iteracion:  5260  =  nan
# Costo despues de iteracion:  5270  =  nan
# Costo despues de iteracion:  5280  =  nan
# Costo despues de iteracion:  5290  =  nan
# Costo despues de iteracion:  5300  =  nan
# Costo despues de iteracion:  5310  =  nan
# Costo despues de iteracion:  5320  =  nan
# Costo despues de iteracion:  5330  =  nan
# Costo despues de iteracion:  5340  =  nan
# Costo despues de iteracion:  5350  =  nan
# Costo despues de iteracion:  5360  =  nan
# Costo despues de iteracion:  5370  =  nan
# Costo despues de iteracion:  5380  =  nan
# Costo despues de iteracion:  5390  =  nan
# Costo despues de iteracion:  5400  =  nan
# Costo despues de iteracion:  5410  =  nan
# Costo despues de iteracion:  5420  =  nan
# Costo despues de iteracion:  5430  =  nan
# Costo despues de iteracion:  5440  =  nan
# Costo despues de iteracion:  5450  =  nan
# Costo despues de iteracion:  5460  =  nan
# Costo despues de iteracion:  5470  =  nan
# Costo despues de iteracion:  5480  =  nan
# Costo despues de iteracion:  5490  =  nan
# Costo despues de iteracion:  5500  =  nan
# Costo despues de iteracion:  5510  =  nan
# Costo despues de iteracion:  5520  =  nan
# Costo despues de iteracion:  5530  =  nan
# Costo despues de iteracion:  5540  =  nan
# Costo despues de iteracion:  5550  =  nan
# Costo despues de iteracion:  5560  =  nan
# Costo despues de iteracion:  5570  =  nan
# Costo despues de iteracion:  5580  =  nan
# Costo despues de iteracion:  5590  =  nan
# Costo despues de iteracion:  5600  =  nan
# Costo despues de iteracion:  5610  =  nan
# Costo despues de iteracion:  5620  =  nan
# Costo despues de iteracion:  5630  =  nan
# Costo despues de iteracion:  5640  =  nan
# Costo despues de iteracion:  5650  =  nan
# Costo despues de iteracion:  5660  =  nan
# Costo despues de iteracion:  5670  =  nan
# Costo despues de iteracion:  5680  =  nan
# Costo despues de iteracion:  5690  =  nan
# Costo despues de iteracion:  5700  =  nan
# Costo despues de iteracion:  5710  =  nan
# Costo despues de iteracion:  5720  =  nan
# Costo despues de iteracion:  5730  =  nan
# Costo despues de iteracion:  5740  =  nan
# Costo despues de iteracion:  5750  =  nan
# Costo despues de iteracion:  5760  =  nan
# Costo despues de iteracion:  5770  =  nan
# Costo despues de iteracion:  5780  =  nan
# Costo despues de iteracion:  5790  =  nan
# Costo despues de iteracion:  5800  =  nan
# Costo despues de iteracion:  5810  =  nan
# Costo despues de iteracion:  5820  =  nan
# Costo despues de iteracion:  5830  =  nan
# Costo despues de iteracion:  5840  =  nan
# Costo despues de iteracion:  5850  =  nan
# Costo despues de iteracion:  5860  =  nan
# Costo despues de iteracion:  5870  =  nan
# Costo despues de iteracion:  5880  =  nan
# Costo despues de iteracion:  5890  =  nan
# Costo despues de iteracion:  5900  =  nan
# Costo despues de iteracion:  5910  =  nan
# Costo despues de iteracion:  5920  =  nan
# Costo despues de iteracion:  5930  =  nan
# Costo despues de iteracion:  5940  =  nan
# Costo despues de iteracion:  5950  =  nan
# Costo despues de iteracion:  5960  =  nan
# Costo despues de iteracion:  5970  =  nan
# Costo despues de iteracion:  5980  =  nan
# Costo despues de iteracion:  5990  =  nan
# Costo despues de iteracion:  6000  =  nan
# Costo despues de iteracion:  6010  =  nan
# Costo despues de iteracion:  6020  =  nan
# Costo despues de iteracion:  6030  =  nan
# Costo despues de iteracion:  6040  =  nan
# Costo despues de iteracion:  6050  =  nan
# Costo despues de iteracion:  6060  =  nan
# Costo despues de iteracion:  6070  =  nan
# Costo despues de iteracion:  6080  =  nan
# Costo despues de iteracion:  6090  =  nan
# Costo despues de iteracion:  6100  =  nan
# Costo despues de iteracion:  6110  =  nan
# Costo despues de iteracion:  6120  =  nan
# Costo despues de iteracion:  6130  =  nan
# Costo despues de iteracion:  6140  =  nan
# Costo despues de iteracion:  6150  =  nan
# Costo despues de iteracion:  6160  =  nan
# Costo despues de iteracion:  6170  =  nan
# Costo despues de iteracion:  6180  =  nan
# Costo despues de iteracion:  6190  =  nan
# Costo despues de iteracion:  6200  =  nan
# Costo despues de iteracion:  6210  =  nan
# Costo despues de iteracion:  6220  =  nan
# Costo despues de iteracion:  6230  =  nan
# Costo despues de iteracion:  6240  =  nan
# Costo despues de iteracion:  6250  =  nan
# Costo despues de iteracion:  6260  =  nan
# Costo despues de iteracion:  6270  =  nan
# Costo despues de iteracion:  6280  =  nan
# Costo despues de iteracion:  6290  =  nan
# Costo despues de iteracion:  6300  =  nan
# Costo despues de iteracion:  6310  =  nan
# Costo despues de iteracion:  6320  =  nan
# Costo despues de iteracion:  6330  =  nan
# Costo despues de iteracion:  6340  =  nan
# Costo despues de iteracion:  6350  =  nan
# Costo despues de iteracion:  6360  =  nan
# Costo despues de iteracion:  6370  =  nan
# Costo despues de iteracion:  6380  =  nan
# Costo despues de iteracion:  6390  =  nan
# Costo despues de iteracion:  6400  =  nan
# Costo despues de iteracion:  6410  =  nan
# Costo despues de iteracion:  6420  =  nan
# Costo despues de iteracion:  6430  =  nan
# Costo despues de iteracion:  6440  =  nan
# Costo despues de iteracion:  6450  =  nan
# Costo despues de iteracion:  6460  =  nan
# Costo despues de iteracion:  6470  =  nan
# Costo despues de iteracion:  6480  =  nan
# Costo despues de iteracion:  6490  =  nan
# Costo despues de iteracion:  6500  =  nan
# Costo despues de iteracion:  6510  =  nan
# Costo despues de iteracion:  6520  =  nan
# Costo despues de iteracion:  6530  =  nan
# Costo despues de iteracion:  6540  =  nan
# Costo despues de iteracion:  6550  =  nan
# Costo despues de iteracion:  6560  =  nan
# Costo despues de iteracion:  6570  =  nan
# Costo despues de iteracion:  6580  =  nan
# Costo despues de iteracion:  6590  =  nan
# Costo despues de iteracion:  6600  =  nan
# Costo despues de iteracion:  6610  =  nan
# Costo despues de iteracion:  6620  =  nan
# Costo despues de iteracion:  6630  =  nan
# Costo despues de iteracion:  6640  =  nan
# Costo despues de iteracion:  6650  =  nan
# Costo despues de iteracion:  6660  =  nan
# Costo despues de iteracion:  6670  =  nan
# Costo despues de iteracion:  6680  =  nan
# Costo despues de iteracion:  6690  =  nan
# Costo despues de iteracion:  6700  =  nan
# Costo despues de iteracion:  6710  =  nan
# Costo despues de iteracion:  6720  =  nan
# Costo despues de iteracion:  6730  =  nan
# Costo despues de iteracion:  6740  =  nan
# Costo despues de iteracion:  6750  =  nan
# Costo despues de iteracion:  6760  =  nan
# Costo despues de iteracion:  6770  =  nan
# Costo despues de iteracion:  6780  =  nan
# Costo despues de iteracion:  6790  =  nan
# Costo despues de iteracion:  6800  =  nan
# Costo despues de iteracion:  6810  =  nan
# Costo despues de iteracion:  6820  =  nan
# Costo despues de iteracion:  6830  =  nan
# Costo despues de iteracion:  6840  =  nan
# Costo despues de iteracion:  6850  =  nan
# Costo despues de iteracion:  6860  =  nan
# Costo despues de iteracion:  6870  =  nan
# Costo despues de iteracion:  6880  =  nan
# Costo despues de iteracion:  6890  =  nan
# Costo despues de iteracion:  6900  =  nan
# Costo despues de iteracion:  6910  =  nan
# Costo despues de iteracion:  6920  =  nan
# Costo despues de iteracion:  6930  =  nan
# Costo despues de iteracion:  6940  =  nan
# Costo despues de iteracion:  6950  =  nan
# Costo despues de iteracion:  6960  =  nan
# Costo despues de iteracion:  6970  =  nan
# Costo despues de iteracion:  6980  =  nan
# Costo despues de iteracion:  6990  =  nan
# Costo despues de iteracion:  7000  =  nan
# Costo despues de iteracion:  7010  =  nan
# Costo despues de iteracion:  7020  =  nan
# Costo despues de iteracion:  7030  =  nan
# Costo despues de iteracion:  7040  =  nan
# Costo despues de iteracion:  7050  =  nan
# Costo despues de iteracion:  7060  =  nan
# Costo despues de iteracion:  7070  =  nan
# Costo despues de iteracion:  7080  =  nan
# Costo despues de iteracion:  7090  =  nan
# Costo despues de iteracion:  7100  =  nan
# Costo despues de iteracion:  7110  =  nan
# Costo despues de iteracion:  7120  =  nan
# Costo despues de iteracion:  7130  =  nan
# Costo despues de iteracion:  7140  =  nan
# Costo despues de iteracion:  7150  =  nan
# Costo despues de iteracion:  7160  =  nan
# Costo despues de iteracion:  7170  =  nan
# Costo despues de iteracion:  7180  =  nan
# Costo despues de iteracion:  7190  =  nan
# Costo despues de iteracion:  7200  =  nan
# Costo despues de iteracion:  7210  =  nan
# Costo despues de iteracion:  7220  =  nan
# Costo despues de iteracion:  7230  =  nan
# Costo despues de iteracion:  7240  =  nan
# Costo despues de iteracion:  7250  =  nan
# Costo despues de iteracion:  7260  =  nan
# Costo despues de iteracion:  7270  =  nan
# Costo despues de iteracion:  7280  =  nan
# Costo despues de iteracion:  7290  =  nan
# Costo despues de iteracion:  7300  =  nan
# Costo despues de iteracion:  7310  =  nan
# Costo despues de iteracion:  7320  =  nan
# Costo despues de iteracion:  7330  =  nan
# Costo despues de iteracion:  7340  =  nan
# Costo despues de iteracion:  7350  =  nan
# Costo despues de iteracion:  7360  =  nan
# Costo despues de iteracion:  7370  =  nan
# Costo despues de iteracion:  7380  =  nan
# Costo despues de iteracion:  7390  =  nan
# Costo despues de iteracion:  7400  =  nan
# Costo despues de iteracion:  7410  =  nan
# Costo despues de iteracion:  7420  =  nan
# Costo despues de iteracion:  7430  =  nan
# Costo despues de iteracion:  7440  =  nan
# Costo despues de iteracion:  7450  =  nan
# Costo despues de iteracion:  7460  =  nan
# Costo despues de iteracion:  7470  =  nan
# Costo despues de iteracion:  7480  =  nan
# Costo despues de iteracion:  7490  =  nan
# Costo despues de iteracion:  7500  =  nan
# Costo despues de iteracion:  7510  =  nan
# Costo despues de iteracion:  7520  =  nan
# Costo despues de iteracion:  7530  =  nan
# Costo despues de iteracion:  7540  =  nan
# Costo despues de iteracion:  7550  =  nan
# Costo despues de iteracion:  7560  =  nan
# Costo despues de iteracion:  7570  =  nan
# Costo despues de iteracion:  7580  =  nan
# Costo despues de iteracion:  7590  =  nan
# Costo despues de iteracion:  7600  =  nan
# Costo despues de iteracion:  7610  =  nan
# Costo despues de iteracion:  7620  =  nan
# Costo despues de iteracion:  7630  =  nan
# Costo despues de iteracion:  7640  =  nan
# Costo despues de iteracion:  7650  =  nan
# Costo despues de iteracion:  7660  =  nan
